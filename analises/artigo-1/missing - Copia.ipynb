# %%
# =========================================================
# INSTALAÇÃO DOS PACOTES
# =========================================================

install.packages("tidyverse")
install.packages("naniar")
install.packages("visdat")
install.packages("MissMech")
install.packages("corrplot")
install.packages("mice")
install.packages("psych")
install.packages("skimr")
install.packages("Rdpack")
# Out:
# Instalando pacote em 'C:/Users/Maxwell/AppData/Local/R/win-library/4.6'
# (como 'lib' não foi especificado)
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# Os pacotes binários baixados estão em
# 	C:\Users\Maxwell\AppData\Local\Temp\Rtmpm4rXDd\downloaded_packages
# Instalando pacote em 'C:/Users/Maxwell/AppData/Local/R/win-library/4.6'
# (como 'lib' não foi especificado)
# package 'naniar' successfully unpacked and MD5 sums checked
#
# Os pacotes binários baixados estão em
# 	C:\Users\Maxwell\AppData\Local\Temp\Rtmpm4rXDd\downloaded_packages
# Instalando pacote em 'C:/Users/Maxwell/AppData/Local/R/win-library/4.6'
# (como 'lib' não foi especificado)
# package 'visdat' successfully unpacked and MD5 sums checked
#
# Os pacotes binários baixados estão em
# 	C:\Users\Maxwell\AppData\Local\Temp\Rtmpm4rXDd\downloaded_packages
# Instalando pacote em 'C:/Users/Maxwell/AppData/Local/R/win-library/4.6'
# (como 'lib' não foi especificado)
# package 'MissMech' successfully unpacked and MD5 sums checked
#
# Os pacotes binários baixados estão em
# 	C:\Users\Maxwell\AppData\Local\Temp\Rtmpm4rXDd\downloaded_packages
# Instalando pacote em 'C:/Users/Maxwell/AppData/Local/R/win-library/4.6'
# (como 'lib' não foi especificado)
# package 'corrplot' successfully unpacked and MD5 sums checked
#
# Os pacotes binários baixados estão em
# 	C:\Users\Maxwell\AppData\Local\Temp\Rtmpm4rXDd\downloaded_packages
# Instalando pacote em 'C:/Users/Maxwell/AppData/Local/R/win-library/4.6'
# (como 'lib' não foi especificado)
# package 'mice' successfully unpacked and MD5 sums checked
#
# Os pacotes binários baixados estão em
# 	C:\Users\Maxwell\AppData\Local\Temp\Rtmpm4rXDd\downloaded_packages
# Instalando pacote em 'C:/Users/Maxwell/AppData/Local/R/win-library/4.6'
# (como 'lib' não foi especificado)
# package 'psych' successfully unpacked and MD5 sums checked
#
# Os pacotes binários baixados estão em
# 	C:\Users\Maxwell\AppData\Local\Temp\Rtmpm4rXDd\downloaded_packages
# Instalando pacote em 'C:/Users/Maxwell/AppData/Local/R/win-library/4.6'
# (como 'lib' não foi especificado)
# package 'skimr' successfully unpacked and MD5 sums checked
#
# Os pacotes binários baixados estão em
# 	C:\Users\Maxwell\AppData\Local\Temp\Rtmpm4rXDd\downloaded_packages
# Instalando pacote em 'C:/Users/Maxwell/AppData/Local/R/win-library/4.6'
# (como 'lib' não foi especificado)
# package 'Rdpack' successfully unpacked and MD5 sums checked
#
# Os pacotes binários baixados estão em
# 	C:\Users\Maxwell\AppData\Local\Temp\Rtmpm4rXDd\downloaded_packages

# %%
# =========================================================
# CARREGAR PACOTES
# =========================================================

library(tidyverse)

# glimpse()
library(dplyr)
library(tidyr)
library(ggplot2)
library(readr)

# visualização de missing
library(naniar)
library(visdat)

# teste MCAR de Little
library(MissMech)

# correlogramas
library(corrplot)

# imputação múltipla
library(mice)

# análises psicométricas futuras
library(psych)

# relatórios descritivos
library(skimr)
# Out:
# corrplot 0.95 loaded
#
#
# Anexando pacote: 'mice'
#
#
# O seguinte objeto é mascarado por 'package:stats':
#
#     filter
#
#
# Os seguintes objetos são mascarados por 'package:base':
#
#     cbind, rbind
#
#
#
# Anexando pacote: 'psych'
#
#
# Os seguintes objetos são mascarados por 'package:ggplot2':
#
#     %+%, alpha
#
#
#
# Anexando pacote: 'skimr'
#
#
# O seguinte objeto é mascarado por 'package:naniar':
#
#     n_complete

# %% [markdown]
# ### ETAPA 1 — BASE DE DADOS

# %%
# =========================================================
# IMPORTAR BASE
# =========================================================

onet <- read.csv(
  "onet-v6.txt",
  check.names = FALSE
)

# Manter apenas linhas com Type == "Skills"
onet <- onet[onet$Type == "Skills" & onet$`Scale ID` == "LV", ]

onet$`Element Name`[
  onet$`Element ID` == "2.B.3.g"
] <- "Operations Monitoring"

# %% [markdown]
# ### ETAPA 2 — CRIAR IDENTIFICADOR ÚNICO

# %%
onet <- onet %>%
  mutate(
    `Element and Scale` =
      paste(
        `Element Name`,
        `Scale Name`,
        sep = " - "
      )
  )

# %% [markdown]
# ### ETAPA 3 — Z-SCORE POR SCALE ID

# %%
onet <- onet %>%
  group_by(`Scale ID`) %>%
  mutate(
    z_Data_Value =
      as.numeric(
        scale(`Data Value`)
      )
  ) %>%
  ungroup()

# %%
summary(onet$z_Data_Value)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -1.8469 -0.7451  0.1492  0.0000  0.6442  3.0394

# %% [markdown]
# ### ETAPA 3.5 — COBERTURA LONGITUDINAL

# %%
# =========================================================
# COBERTURA LONGITUDINAL
# =========================================================

coverage_year <- onet %>%
  group_by(`Version Year`) %>%
  summarise(
    ocupacoes = n_distinct(`O*NET-SOC Code`),
    elementos = n_distinct(`Element and Scale`)
  )

coverage_year

ggplot(
  coverage_year,
  aes(
    x = `Version Year`,
    y = ocupacoes
  )
) +
  geom_line() +
  geom_point(size = 3) +
  theme_minimal() +
  labs(
    title = "Número de ocupações por ano",
    x = "Ano",
    y = "Ocupações"
  )
# Out:
#   Version Year ocupacoes elementos
# 1 2017         683       35
# 2 2019         612       35
# 3 2021         715       35
# 4 2023         715       35
# 5 2025         725       35
# plot without title

# %% [markdown]
# ### ETAPA 4 — CONSTRUIR PAINEL LONGITUDINAL

# %%
anos_disponiveis <-
  sort(
    unique(
      onet$`Version Year`
    )
  )

anos_disponiveis
# Out:
# [1] 2017 2019 2021 2023 2025

# %%
occ_long <- onet %>%
  group_by(`O*NET-SOC Code`) %>%
  summarise(
    n_years =
      n_distinct(`Version Year`)
  ) %>%
  filter(
    n_years ==
      length(anos_disponiveis)
  )

# %%
sample_long <- onet %>%
  filter(
    `O*NET-SOC Code`
    %in%
    occ_long$`O*NET-SOC Code`
  )

# %%
retention_report <- tibble(

  indicador = c(
    "Ocupações originais",
    "Ocupações longitudinais"
  ),

  valor = c(
    n_distinct(
      onet$`O*NET-SOC Code`
    ),
    n_distinct(
      sample_long$`O*NET-SOC Code`
    )
  )
)

retention_report
# Out:
#   indicador               valor
# 1 Ocupações originais     798
# 2 Ocupações longitudinais 610

# %%
100 *
n_distinct(
  sample_long$`O*NET-SOC Code`
) /
n_distinct(
  onet$`O*NET-SOC Code`
)
# Out:
# [1] 76.4411

# %%
balance_check <- sample_long %>%
  group_by(`O*NET-SOC Code`) %>%
  summarise(
    anos =
      n_distinct(
        `Version Year`
      ),
    .groups = "drop"
  )

summary(balance_check$anos)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       5       5       5       5       5       5

# %% [markdown]
# ### ETAPA 5 — TRANSFORMAR PARA WIDE

# %%
panel_wide <- sample_long %>%
  select(
    `O*NET-SOC Code`,
    Title,
    `Version Year`,
     # `Year`,
    `Element and Scale`,
    z_Data_Value
  ) %>%
  pivot_wider(
    names_from =
      `Element and Scale`,
    values_from =
      z_Data_Value,
    values_fn =
      mean
  )

# %%
dim(panel_wide)
# Out:
# [1] 3050   38

# %% [markdown]
# ### ETAPA 6 — RELATÓRIO DE MISSING

# %%
global_missing <-
  mean(
    is.na(panel_wide)
  ) * 100

global_missing
# Out:
# [1] 0.2450388

# %%
missing_var <- panel_wide %>%
  summarise(
    across(
      everything(),
      ~ mean(is.na(.))*100
    )
  ) %>%
  pivot_longer(
    everything(),
    names_to =
      "variable",
    values_to =
      "missing_pct"
  ) %>%
  arrange(
    desc(missing_pct)
  )

# %%
head(missing_var,35)
# Out:
#    variable                                  missing_pct
# 1  Operations Analysis - Level               2.26229508
# 2  Technology Design - Level                 1.08196721
# 3  Programming - Level                       1.04918033
# 4  Installation - Level                      0.75409836
# 5  Quality Control Analysis - Level          0.68852459
# 6  Science - Level                           0.49180328
# 7  Management of Financial Resources - Level 0.49180328
# 8  Equipment Selection - Level               0.49180328
# 9  Mathematical Reasoning - Level            0.36065574
# 10 Systems Evaluation - Level                0.32786885
# 11 Troubleshooting - Level                   0.22950820
# 12 Management of Material Resources - Level  0.19672131
# 13 Negotiation - Level                       0.16393443
# 14 Management of Personnel Resources - Level 0.13114754
# 15 Operations Monitoring - Level             0.09836066
# 16 Equipment Maintenance - Level             0.09836066
# 17 Systems Analysis - Level                  0.09836066
# 18 Persuasion - Level                        0.06557377
# 19 Operation and Control - Level             0.06557377
# 20 Repairing - Level                         0.06557377
# 21 Coordination - Level                      0.03278689
# 22 Service Orientation - Level               0.03278689
# 23 Judgment and Decision Making - Level      0.03278689
# 24 O*NET-SOC Code                            0.00000000
# 25 Title                                     0.00000000
# 26 Version Year                              0.00000000
# 27 Reading Comprehension - Level             0.00000000
# 28 Active Listening - Level                  0.00000000
# 29 Writing - Level                           0.00000000
# 30 Speaking - Level                          0.00000000
# 31 Critical Thinking - Level                 0.00000000
# 32 Active Learning - Level                   0.00000000
# 33 Learning Strategies - Level               0.00000000
# 34 Monitoring - Level                        0.00000000
# 35 Social Perceptiveness - Level             0.00000000

# %%
missing_year <- panel_wide %>%
  group_by(`Version Year`) %>%
  summarise(
    missing_pct =
      mean(
        is.na(across(everything()))
      )*100
  )

# %%
missing_year
# Out:
#   Version Year missing_pct
# 1 2017         0.70004431
# 2 2019         0.36331413
# 3 2021         0.10633584
# 4 2023         0.05316792
# 5 2025         0.03544528

# %% [markdown]
# ### ETAPA 7 — VISUALIZAÇÕES

# %%
ggplot(
  classification_report,
  aes(
    x = reorder(categoria, n),
    y = n
  )
) +
  geom_col() +
  coord_flip() +
  theme_minimal(base_size = 14) +
  labs(
    title = "Classification of O*NET variables by missingness",
    x = "",
    y = "Number of variables"
  )
# Out:
# plot without title

# %%
ggplot(
  classified_vars,
  aes(x = missing_pct)
) +
  geom_histogram(
    bins = 30
  ) +
  theme_minimal(base_size = 14) +
  labs(
    title = "Distribution of missingness across variables",
    x = "% Missing",
    y = "Frequency"
  )
# Out:
# plot without title

# %%
top_missing <- classified_vars %>%
  slice_max(
    missing_pct,
    n = 30
  )

# %%
ggplot(
  top_missing,
  aes(
    x = reorder(variable, missing_pct),
    y = missing_pct
  )
) +
  geom_col() +
  coord_flip() +
  theme_minimal(base_size = 12) +
  labs(
    title = "30 variables with highest missingness",
    x = "",
    y = "% Missing"
  )
# Out:
# plot without title

# %%
ggplot(
  missing_year,
  aes(
    x = `Version Year`,
    y = missing_pct
  )
) +
  geom_line() +
  geom_point(size = 3) +
  theme_minimal(base_size = 14) +
  labs(
    title = "Missingness over time",
    x = "Version Year",
    y = "% Missing"
  )
# Out:
# plot without title

# %%
quality_report <- tibble(

  Metric = c(
    "Original occupations",
    "Balanced-panel occupations",
    "Retention (%)",
    "Years",
    "Variables",
    "Observations"
  ),

  Value = c(
    798,
    610,
    round(610/798*100,2),
    length(unique(panel_wide$`Version Year`)),
    ncol(panel_wide)-3,
    nrow(panel_wide)
  )
)

quality_report
# Out:
#   Metric                     Value
# 1 Original occupations        798.00
# 2 Balanced-panel occupations  610.00
# 3 Retention (%)                76.44
# 4 Years                         5.00
# 5 Variables                    35.00
# 6 Observations               3050.00

# %%
# =========================================================
# GRÁFICO LONGITUDINAL - ÍNDICE BASE 100
# =========================================================

occupations_year <- onet %>%
  group_by(`Version Year`) %>%
  summarise(
    ocupacoes_originais =
      n_distinct(`O*NET-SOC Code`),
    .groups = "drop"
  )

balanced_year <- sample_long %>%
  group_by(`Version Year`) %>%
  summarise(
    ocupacoes_painel =
      n_distinct(`O*NET-SOC Code`),
    .groups = "drop"
  )

plot_data <- occupations_year %>%
  left_join(
    balanced_year,
    by = "Version Year"
  ) %>%
  left_join(
    missing_year,
    by = "Version Year"
  ) %>%
  mutate(

    ocupacoes_originais =
      ocupacoes_originais /
      first(ocupacoes_originais) * 100,

    ocupacoes_painel =
      ocupacoes_painel /
      first(ocupacoes_painel) * 100,

    missing_pct =
      missing_pct /
      first(missing_pct) * 100
  ) %>%
  pivot_longer(
    -`Version Year`,
    names_to = "serie",
    values_to = "indice"
  )

ggplot(
  plot_data,
  aes(
    x = `Version Year`,
    y = indice,
    group = serie,
    linetype = serie
  )
) +
  geom_line(
    linewidth = 1.2
  ) +
  geom_point(
    size = 3
  ) +
  theme_minimal(base_size = 14) +
  theme(
    aspect.ratio = 0.45
  ) +
  labs(
    title = "",
    x = "Year",
    y = "",
    linetype = ""
  )
# Out:
# plot without title

# %% [markdown]
# ### ETAPA 8 — CLASSIFICAÇÃO DAS VARIÁVEIS

# %%
classified_vars <- missing_var %>%
  mutate(
    categoria =
      case_when(

        missing_pct <= 5 ~
          "core_stable",

        missing_pct <= 30 ~
          "transitional",

        missing_pct <= 70 ~
          "emergent",

        TRUE ~
          "sparse"
      )
  )

# %%
classification_report <- classified_vars %>%
  count(categoria) %>%
  mutate(
    percentual =
      round(
        n/sum(n)*100,
        2
      )
  ) %>%
  arrange(desc(n))

classification_report
# Out:
#   categoria   n  percentual
# 1 core_stable 38 100

# %% [markdown]
# ### ETAPA 9 — MATRIZ FINAL

# %%
valid_vars <- classified_vars %>%
  filter(
    categoria != "sparse"
  ) %>%
  pull(variable)

# %% [markdown]
# ### ETAPA 10 — EXPORTAÇÃO

# %%
write.table(
  panel_wide,
  "missing-c.txt",
  sep = "\t",
  quote = FALSE,
  row.names = FALSE,
  fileEncoding = "UTF-8"
)
