# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
tech = pd.read_excel("Technology_Skills.xlsx")
skills = pd.read_excel("Skills.xlsx")
activities = pd.read_excel("Work_Activities.xlsx")

# %%
tech.columns = tech.columns.str.strip()
skills.columns = skills.columns.str.strip()
activities.columns = activities.columns.str.strip()

# %%
print(tech.columns)
print(skills.columns)
print(activities.columns)
# Out:
# Index(['O*NET-SOC Code', 'Title', 'Example', 'Commodity Code',
#        'Commodity Title', 'Hot Technology', 'In Demand'],
#       dtype='object')
# Index(['O*NET-SOC Code', 'Title', 'Element ID', 'Element Name', 'Scale ID',
#        'Scale Name', 'Data Value', 'N', 'Standard Error', 'Lower CI Bound',
#        'Upper CI Bound', 'Recommend Suppress', 'Not Relevant', 'Date',
#        'Domain Source'],
#       dtype='object')
# Index(['O*NET-SOC Code', 'Title', 'Element ID', 'Element Name', 'Scale ID',
#        'Scale Name', 'Data Value', 'N', 'Standard Error', 'Lower CI Bound',
#        'Upper CI Bound', 'Recommend Suppress', 'Not Relevant', 'Date',
#        'Domain Source'],
#       dtype='object')

# %%
for s in sorted(skills["Element Name"].unique()):
    print(s)
# Out:
# Active Learning
# Active Listening
# Complex Problem Solving
# Coordination
# Critical Thinking
# Equipment Maintenance
# Equipment Selection
# Installation
# Instructing
# Judgment and Decision Making
# Learning Strategies
# Management of Financial Resources
# Management of Material Resources
# Management of Personnel Resources
# Mathematics
# Monitoring
# Negotiation
# Operation and Control
# Operations Analysis
# Operations Monitoring
# Persuasion
# Programming
# Quality Control Analysis
# Reading Comprehension
# Repairing
# Science
# Service Orientation
# Social Perceptiveness
# Speaking
# Systems Analysis
# Systems Evaluation
# Technology Design
# Time Management
# Troubleshooting
# Writing

# %%
for a in sorted(activities["Element Name"].unique()):
    print(a)
# Out:
# Analyzing Data or Information
# Assisting and Caring for Others
# Coaching and Developing Others
# Communicating with People Outside the Organization
# Communicating with Supervisors, Peers, or Subordinates
# Controlling Machines and Processes
# Coordinating the Work and Activities of Others
# Developing Objectives and Strategies
# Developing and Building Teams
# Documenting/Recording Information
# Drafting, Laying Out, and Specifying Technical Devices, Parts, and Equipment
# Establishing and Maintaining Interpersonal Relationships
# Estimating the Quantifiable Characteristics of Products, Events, or Information
# Evaluating Information to Determine Compliance with Standards
# Getting Information
# Guiding, Directing, and Motivating Subordinates
# Handling and Moving Objects
# Identifying Objects, Actions, and Events
# Inspecting Equipment, Structures, or Materials
# Interpreting the Meaning of Information for Others
# Judging the Qualities of Objects, Services, or People
# ...

# %%
tech_skills = [
    "Programming",
    "Systems Analysis",
    "Systems Evaluation",
    "Technology Design",
    "Operations Analysis"
]

# %%
tech_activities = [
    "Working with Computers",
    "Processing Information",
    "Analyzing Data or Information",
    "Updating and Using Relevant Knowledge"
]

# %%
act_f = activities[
    (activities["Element Name"].isin(tech_activities)) &
    (activities["Scale ID"] == "IM")
]

act_agg = act_f.groupby("O*NET-SOC Code")["Data Value"].mean()
act_agg.name = "tech_activity_score"

# %%
skills_f = skills[
    (skills["Element Name"].isin(tech_skills)) &
    (skills["Scale ID"] == "IM")
]

skills_agg = skills_f.groupby("O*NET-SOC Code")["Data Value"].mean()
skills_agg.name = "tech_skill_score"

# %%
tech_agg = tech.groupby("O*NET-SOC Code").agg(
    n_tech = ("Example", "nunique"),
    n_hot = ("Hot Technology", lambda x: (x=="Y").sum()),
    n_demand = ("In Demand", lambda x: (x=="Y").sum())
)

# %%
df = tech_agg.join(skills_agg).join(act_agg).fillna(0)

# %%
from sklearn.preprocessing import StandardScaler

features = ["n_tech", "n_hot", "n_demand", "tech_skill_score", "tech_activity_score"]

scaler = StandardScaler()
X = scaler.fit_transform(df[features])

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=1)
df["theta"] = pca.fit_transform(X)

# %%
df.sort_values("theta", ascending=False).head(10)
# Out:
#                 n_tech  n_hot  n_demand  tech_skill_score  \
# O*NET-SOC Code
# 15-1252.00         429    148        33             3.502
# 15-1254.00         251    122        41             3.272
# 15-1253.00         428    124        22             3.146
# 15-1242.00         288    110        32             3.024
# 15-1299.08         265    129        25             3.502
# 15-1251.00         294    103        19             3.424
# 15-1243.00         324    112        13             3.300
# 15-1211.00         313    119        11             3.326
# 15-1299.09         334    121         9             2.800
# 15-1244.00         266     95        19             3.424
#
#                 tech_activity_score      theta
# O*NET-SOC Code
# 15-1252.00                   4.3225  12.921238
# 15-1254.00                   4.2100  10.871202
# 15-1253.00                   4.4850  10.815995
# 15-1242.00                   4.1075   9.731097
# 15-1299.08                   4.1600   9.633033
# ...

# %%
import numpy as np

df["n_tech_log"] = np.log1p(df["n_tech"])
df["n_hot_log"] = np.log1p(df["n_hot"])
df["n_demand_log"] = np.log1p(df["n_demand"])

# %%
features = [
    "n_tech_log",
    "n_hot_log",
    "n_demand_log",
    "tech_skill_score",
    "tech_activity_score"
]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

scaler = StandardScaler()
X = scaler.fit_transform(df[features])

pca = PCA(n_components=1)
df["theta_refined"] = pca.fit_transform(X)

# %%
df.sort_values("theta_refined", ascending=False).head(10)
# Out:
#                 n_tech  n_hot  n_demand  tech_skill_score  \
# O*NET-SOC Code
# 15-1252.00         429    148        33             3.502
# 15-1253.00         428    124        22             3.146
# 15-1254.00         251    122        41             3.272
# 15-1299.08         265    129        25             3.502
# 15-1251.00         294    103        19             3.424
# 15-1243.00         324    112        13             3.300
# 15-1242.00         288    110        32             3.024
# 15-1211.00         313    119        11             3.326
# 15-1221.00         163     73        30             3.446
# 15-1241.00         283    101        14             3.502
#
#                 tech_activity_score      theta  n_tech_log  n_hot_log  \
# O*NET-SOC Code
# 15-1252.00                   4.3225  12.921238    6.063785   5.003946
# 15-1253.00                   4.4850  10.815995    6.061457   4.828314
# 15-1254.00                   4.2100  10.871202    5.529429   4.812184
# ...

# %%
df[features].corr()
# Out:
#                      n_tech_log  n_hot_log  n_demand_log  tech_skill_score  \
# n_tech_log             1.000000   0.858531      0.695078          0.471898
# n_hot_log              0.858531   1.000000      0.712887          0.436740
# n_demand_log           0.695078   0.712887      1.000000          0.359294
# tech_skill_score       0.471898   0.436740      0.359294          1.000000
# tech_activity_score    0.402817   0.346099      0.320694          0.834268
#
#                      tech_activity_score
# n_tech_log                      0.402817
# n_hot_log                       0.346099
# n_demand_log                    0.320694
# tech_skill_score                0.834268
# tech_activity_score             1.000000

# %%
print(pca.components_)
# Out:
# [[0.49155643 0.48195159 0.43956308 0.42330708 0.39203362]]

# %%
# índice 1: infraestrutura tecnológica
infra_features = ["n_tech_log","n_hot_log","n_demand_log"]

# índice 2: uso tecnológico no trabalho
use_features = ["tech_skill_score","tech_activity_score"]

# %%
pca1 = PCA(n_components=1)
df["theta_infra"] = pca1.fit_transform(StandardScaler().fit_transform(df[infra_features]))

pca2 = PCA(n_components=1)
df["theta_use"] = pca2.fit_transform(StandardScaler().fit_transform(df[use_features]))

# %%
df["theta_infra"].corr(df["theta_use"])
# Out:
# 0.44547193675055247

# %%
df.head(10)
# Out:
#                 n_tech  n_hot  n_demand  tech_skill_score  \
# O*NET-SOC Code
# 11-1011.00          49     16         4             2.998
# 11-1011.03          21     14         4             2.880
# 11-1021.00         146     49         3             2.348
# 11-1031.00          32     11         0             0.000
# 11-2011.00          73     27         6             2.498
# 11-2021.00         153     67         6             2.752
# 11-2022.00         103     39         5             2.596
# 11-2032.00          66     29         5             0.000
# 11-2033.00          61     24         8             2.350
# 11-3012.00          56     22         5             2.300
#
#                 tech_activity_score     theta  n_tech_log  n_hot_log  \
# O*NET-SOC Code
# 11-1011.00                   4.3300  1.334697    3.912023   2.833213
# 11-1011.03                   4.1575  0.824311    3.091042   2.708050
# 11-1021.00                   4.0950  2.741362    4.990433   3.912023
# ...
